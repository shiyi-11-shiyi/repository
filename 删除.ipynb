# %%
from typing import Iterable,Any
class DeleteItem:
    """
    在列表中删除元素
    """
    def __init__(self,iterable:Iterable[Any]):
        """
        param iterable: 可迭代对象，内部删除元素
        """
        self.iterable = list(iterable)
    def Delete(self,index_to_Delete: int) -> list[Any]:
        """
        删除元素
        :param index_to_Delete:删除的索引
        """
        length : int = len(self.iterable)
        if index_to_Delete >= length or index_to_Delete < 0:
            raise IndexError("输入的数字超出范围")
        for i in range(index_to_Delete,length-1,1):
            self.iterable[i] = self.iterable[i+1]
        self.iterable.pop()
        return self.iterable

# %%
f = DeleteItem([0,1,2,3,4,5,6,7,8])
print(f.Delete(3))
ff = DeleteItem([0,11,22,33,44])
print(f.Delete(0))
# Out:
# [0, 1, 2, 4, 5, 6, 7, 8]
# [1, 2, 4, 5, 6, 7, 8]
